# %% [markdown]
# # Лабораторная работа по МО №1
#
# Выполнил: Еремин Илья Владимирович, гр. 3374
#
# ## 1. Описание предметной области датасета
# В данной лабораторной работе исследуется набор данных в области мировой экономики. В нём содержится индекс стоимости жизни по странам. Данные реальны, представлены за середину 2024 г. и взяты из [Numbeo](http://www.numbeo.com/cost-of-living/rankings_by_country.jsp).
# В таблице набора данных представлено 8 атрибутов:
# - `Классификация по рангу` (Числовой тип данных)
# - `Страна` (Строковый тип данных)
# - `Индекс стоимости жизни` (Числовой тип данных)
# - `Индекс арендной платы` (Числовой тип данных)
# - `Индекс стоимости жизни и арендной платы` (Числовой тип данных)
# - `Индекс продуктов питания` (Числовой тип данных)
# - `Индекс цен в ресторанах` (Числовой тип данных)
# - `Индекс местной покупательной способности` (Числовой тип данных)
#
# ## 2. Анализ атрибутов
# В таблице представлено среднее значение и СКО для каждого атрибута:
# | Название атрибута                            | Среднее значение | СКО         |
# |----------------------------------------------|------------------|-------------|
# | Индекс стоимости жизни                       | 43.6             | 31289.3     |
# | Индекс арендной платы                        | 16.1             | 15628.8     |
# | Индекс стоимости жизни и арендной платы      | 30.4             | 21111.2     |
# | Индекс продуктов питания                     | 44.2             | 34905.2     |
# | Индекс цен в ресторанах                      | 36.5             | 40003       |
# | Индекс местной покупательной способности     | 65.1             | 187885.6    |
#
# Далее представлены гистограммы распределения значений для каждого атрибута:
# ![gist1.png](attachment:e9b8d1a5-3683-4bf3-85d1-9de6d6e341fe.png)
# ![gist2.png](attachment:ea1c2462-4615-4ed8-bc41-02387d282236.png)
# ![gist3.png](attachment:9e76d930-9aff-40cd-be51-f70bb05af22a.png)
# ![gist4.png](attachment:e51fd4cd-55b9-40ce-8ad4-31cfe0031c3c.png)
# ![gist5.png](attachment:4ddc8092-9504-4785-91dc-8eaec76e8227.png)
# ![gist6.png](attachment:c1a4f2ef-c97f-4e4d-bab6-3537aae3c935.png)
#
# В ходе анализа гистограмм выбросов и пропущенных значений не было обнаружено.
# ## 3. Определение корреляции атрибутов
# С помощью пакета анализа данных в Excel была построена матрица корреляции, по которой можно наглядно увидеть высококоррелированные значения. Такими значениями обладают атрибуты: индекс стоимости жизни, индекс стоимости жизни и арендной платы. Низкую корреляцию имеет атрибут индекса местной покупательной способности. Корреляцию не имеют атрибуты классификации по рангу и название страны.
#
# ### Матрица корреляции:
# ![matrkor.png](attachment:14a83045-5359-4342-b35c-8b020c88bd74.png)
#
# Далее был создан график рассеивания. Здесь можно увидеть, что практически все атрибуты образуют положительную линию тренда, а значит и высокую корреляцию. Но точки атрибута индекса местной покупательной способности довольно разбросаны по графику. Значит этот атрибут имеет низкую корреляцию.
#
# ### График рассеивания:
# ![graph1.png](attachment:40f93cc6-6832-49cd-a516-4620a7b64b0d.png)
#
# ## Вывод
# В ходе данной лабораторной работы был исследован набор данных об индексе стоимости жизни и не только. При помощи программы Excel удалось правильно отобразить данные, рассчитать средние значения, построить графики, гистограммы и матрицы. Проанализировав данные можно сделать вывод, что большинство атрибутов имеет высокую корреляцию, выбросов и пропущенных значений обнаружено не было.
